# %%
# %run data_preprocessing.ipynb import X_train, X_test, y_test, y_train, names
# Out:
# ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'corn' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'tomato' 'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut'
#  'cotton' 'jute' 'weed' 'coffee']
# [21 12  3 10 19  6 14 15  2 11 20  1 13  8 22 23 16  0 17 18  4  7  9 24
#   5]
# c:\Python310\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## 2) LightGBM model
#
# LightGBM uses tree-based learning algorithms. It is particularly well-suited for large datasets or datasets with a large number of features.

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
lgbModel = lgb.LGBMClassifier()
lgbModel.fit(X_train, y_train)
y_predict = lgbModel.predict(X_test)

# %%
accuracy = accuracy_score(y_predict, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_predict)))
# Out:
# LightGBM Model accuracy score: 0.8232

# %%
confusion = confusion_matrix(y_test ,y_predict)
plt.figure(figsize=(8,8))
sns.heatmap(confusion,annot=True)
plt.xlabel("Predicted plant")
plt.ylabel("Actual plant")
# Out:
# Text(67.25, 0.5, 'Actual plant')

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        28
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        24
#            5       0.17      0.12      0.14        33
#            6       0.24      0.32      0.27        28
#            7       0.48      0.45      0.46        29
#            8       1.00      1.00      1.00        35
#            9       0.15      0.14      0.15        28
#           10       1.00      1.00      1.00        28
#           11       0.96      1.00      0.98        25
#           12       1.00      0.97      0.98        31
#           13       0.97      1.00      0.99        35
#           14       1.00      0.97      0.98        31
#           15       1.00      1.00      1.00        24
# ...

# %%
#testing 
names.sort()
print(names[lgbModel.predict([[90, 42, 43, 20.879744, 75, 5.5,220]])])
# Out:
# ['rice']
